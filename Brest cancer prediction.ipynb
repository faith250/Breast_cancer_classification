# %%
import numpy as np
import pandas as pd

# %% [raw]
# Reading the data set and displaying the heading

# %%
breast=pd.read_csv("data.csv")
breast.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# M-malignant-breast cancer-true
# B-benign-breast cancer =false

# %%
breast['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [raw]
# Exploring and understanding the dataset

# %% [raw]
# The meaning of each of the attributes that are shown when the cancer occurs
# id: A unique identifier for each patient
# diagnosis: Whether the diagnosis is malignant (M) or benign (B)
# radius_mean: Mean of distances from center to points on the perimeter
# texture_mean: Standard deviation of gray-scale values
# perimeter_mean: Perimeter of the tumor
# area_mean: Area of the tumor
# smoothness_mean: Local variation in radius lengths
# compactness_mean: Perimeter^2 / area - 1.0
# concavity_mean: Severity of concave portions of the contour
# concave points_mean: Number of concave portions of the contour
# symmetry_mean: Symmetry of tumor
# fractal_dimension_mean: "Coastline approximation" - 1
# radius_se: Standard error of mean of distances from center to points on the perimeter
# texture_se: Standard error of gray-scale values
# perimeter_se: Standard error of perimeter
# area_se: Standard error of area
# smoothness_se: Standard error of local variation in radius lengths
# compactness_se: Standard error of perimeter^2 / area - 1.0
# concavity_se: Standard error of severity of concave portions of the contour
# concave points_se: Standard error for number of concave portions of the contour
# symmetry_se: Standard error for symmetry of tumor
# fractal_dimension_se: Standard error for "coastline approximation" - 1
# radius_worst: "Worst" or largest mean value for mean of distances from center to points on the perimeter
# texture_worst: "Worst" or largest mean value for standard deviation of gray-scale values
# perimeter_worst: "Worst" or largest mean value for perimeter
# area_worst: "Worst" or largest mean value for area
# smoothness_worst: "Worst" or largest mean value for local variation in radius lengths
# compactness_worst: "Worst" or largest mean value for perimeter^2 / area - 1.0
# concavity_worst: "Worst" or largest mean value for severity of concave portions of the contour
# concave points_worst: "Worst" or largest mean value for number of concave portions of the contour
# symmetry_worst: "Worst" or largest mean value for symmetry of tumor
# fractal_dimension_worst: "Worst" or largest mean value for "coastline approximation" - 1

# %% [raw]
# Shape of the dataset

# %%
breast.shape
# Out:
# (569, 33)

# %% [raw]
# Checking null values

# %%
breast.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [raw]
#  Finding Duplicated values

# %%
breast.duplicated().sum()
# Out:
# 0

# %%
breast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [raw]
# Describe gives all the nessary mathematical precalculated values

# %%
breast.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [raw]
# Getting numbers of how ht edata is correlated

# %%
print(breast['diagnosis'].unique())
# Out:
# ['M' 'B']

# %%
# Converting categorical column to numeric if it's needed
breast['diagnosis'] = breast['diagnosis'].map({'M': 1, 'B': 0})  # Example for mapping 'M' and 'B' to 1 and 0

# %%
breast
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
breast.corr()
#negative and positive correlation
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
breast.drop('Unnamed: 32',axis=1,inplace=True)

# %%
#encoding the target variable
#from sklearn.preprocessing import LabelEncoder
#le=LabelEncoder()

# %%
breast['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
print(breast.columns)
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
breast.shape
# Out:
# (569, 32)

# %% [raw]
# Spliting the data into testing and training set

# %%
x=breast.drop('diagnosis',axis=1)
y=breast['diagnosis']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
x.shape
# Out:
# (569, 31)

# %%
from sklearn.model_selection import train_test_split

# %%
#splitting to 20 testing 80 training
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (455, 31)

# %%
x_test.shape
# Out:
# (114, 31)

# %%
#feature scaling as the values are not in standardised form

# %%
x_train
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 68     859471        9.029         17.33           58.79      250.5
# 181    873593       21.090         26.57          142.70     1311.0
# 63     859196        9.173         13.86           59.20      260.9
# 248  88466802       10.650         25.22           68.01      347.0
# 60     858970       10.170         14.88           64.55      311.9
# ..        ...          ...           ...             ...        ...
# 71     859711        8.888         14.64           58.79      244.0
# 106    863031       11.640         18.33           75.17      412.5
# 270   8910721       14.290         16.82           90.30      632.6
# 435    908489       13.980         19.62           91.12      599.5
# 102    862965       12.180         20.52           77.22      458.7
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#bringing all the values in range 
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
sc.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train=sc.transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.23712699, -1.44075296, -0.43531947, ...,  0.9320124 ,
#          2.09724217,  1.88645014],
#        [-0.23702031,  1.97409619,  1.73302577, ...,  2.6989469 ,
#          1.89116053,  2.49783848],
#        [-0.23712907, -1.39998202, -1.24962228, ..., -0.97023893,
#          0.59760192,  0.0578942 ],
#        ...,
#        [-0.17630431,  0.04880192, -0.55500086, ..., -1.23903365,
#         -0.70863864, -1.27145475],
#        [-0.23675669, -0.03896885,  0.10207345, ...,  1.05001236,
#          0.43432185,  1.21336207],
#        [-0.2371006 , -0.54860557,  0.31327591, ..., -0.61102866,
#         -0.3345212 , -0.84628745]])

# %% [raw]
# Training a model

# %% [raw]
# Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
y_pred=lg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263158

# %% [raw]
# Prediction system

# %%
x_train[10]
# Out:
# array([-0.23711093, -0.4976419 ,  0.61365274, -0.49813131, -0.53102815,
#        -0.57694824, -0.17494424, -0.36215622, -0.284859  ,  0.43345165,
#         0.17818232, -0.36844966,  0.55310406, -0.31671104, -0.40524636,
#         0.04025752, -0.03795529, -0.18043065,  0.16478901, -0.12170969,
#         0.23079329, -0.50044002,  0.81940367, -0.46922838, -0.53308833,
#        -0.04910117, -0.04160193, -0.14913653,  0.09681787,  0.10617647,
#         0.49035329])

# %%
input_text=(-0.23711093, -0.4976419 ,  0.61365274, -0.49813131, -0.53102815,
       -0.57694824, -0.17494424, -0.36215622, -0.284859  ,  0.43345165,
        0.17818232, -0.36844966,  0.55310406, -0.31671104, -0.40524636,
        0.04025752, -0.03795529, -0.18043065,  0.16478901, -0.12170969,
        0.23079329, -0.50044002,  0.81940367, -0.46922838, -0.53308833,
       -0.04910117, -0.04160193, -0.14913653,  0.09681787,  0.10617647,
        0.49035329)
np_df=np.asarray(input_text)
prediction=lg.predict(np_df.reshape(1,-1))

if prediction[0]==1:
    print("You have cancer ")
else:
    print("lets goo you r healthy")
# Out:
# lets goo you r healthy

# %%
input_text=(-0.23711093, -0.2 ,  0.61365274, -0.49813131, -0.53102815,
       -0.57694824, -0.17494424, -0.36215622, -0.284859  ,  0.43345165,
        0.17818232, -0.36996,  0.55310406, -0.31671104, -0.40524636,
        0.5, -0.03795529, -0.18043065,  0.7, -0.12170969,
        0.23079329, -0.50044002,  0.81940367, -0.46922838, -0.53308833,
       -0.04910117, -0.04160193, -0.14913653,  0.09681787,  0.10617647,
        0.5)
np_df=np.asarray(input_text)
prediction=lg.predict(np_df.reshape(1,-1))

if prediction[0]==1:
    print("You have cancer ")
else:
    print("lets goo you r healthy")
# Out:
# lets goo you r healthy

# %%
import pickle
pickle.dump(lg,open('model.pkl','wb'))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_pred)
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print(f'ROC AUC: {auc:.4f}')

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
print("Logistic Regression:")
evaluate_model(lr, x_test, y_test)
# Out:
# Logistic Regression:
# Accuracy: 0.9737
# Precision: 0.9762
# Recall: 0.9535
# F1 Score: 0.9647
# ROC AUC: 0.9697

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
print("K-Nearest Neighbors:")
evaluate_model(knn, x_test, y_test)
# Out:
# K-Nearest Neighbors:
# Accuracy: 0.9474
# Precision: 0.9302
# Recall: 0.9302
# F1 Score: 0.9302
# ROC AUC: 0.9440

# %%
svm = SVC(kernel='linear', probability=True)
svm.fit(x_train, y_train)
print("Support Vector Machine:")
evaluate_model(svm, x_test, y_test)
# Out:
# Support Vector Machine:
# Accuracy: 0.9561
# Precision: 0.9318
# Recall: 0.9535
# F1 Score: 0.9425
# ROC AUC: 0.9556

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train, y_train)
print("Decision Tree:")
evaluate_model(dt, x_test, y_test)
# Out:
# Decision Tree:
# Accuracy: 0.9386
# Precision: 0.9091
# Recall: 0.9302
# F1 Score: 0.9195
# ROC AUC: 0.9369

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
print("Random Forest:")
evaluate_model(rf, X_test, y_test)
# Out:
# Random Forest:
# Accuracy: 0.9649
# Precision: 0.9756
# Recall: 0.9302
# F1 Score: 0.9524
# ROC AUC: 0.9581

# %%
gb = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
gb.fit(x_train, y_train)
print("Gradient Boosting:")
evaluate_model(gb, x_test, y_test)
# Out:
# Gradient Boosting:
# Accuracy: 0.9474
# Precision: 0.9302
# Recall: 0.9302
# F1 Score: 0.9302
# ROC AUC: 0.9440

# %%
nb = GaussianNB()
nb.fit(x_train, y_train)
print("Naive Bayes:")
evaluate_model(nb, x_test, y_test)
# Out:
# Naive Bayes:
# Accuracy: 0.9649
# Precision: 0.9756
# Recall: 0.9302
# F1 Score: 0.9524
# ROC AUC: 0.9581

# %%
ann = MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42)
ann.fit(x_train, y_train)
print("Artificial Neural Network:")
evaluate_model(ann, x_test, y_test)
# Out:
# Artificial Neural Network:
# Accuracy: 0.9649
# Precision: 0.9535
# Recall: 0.9535
# F1 Score: 0.9535
# ROC AUC: 0.9627

# %%
qda = QuadraticDiscriminantAnalysis()
qda.fit(x_train, y_train)
print("Quadratic Discriminant Analysis:")
evaluate_model(qda,x_test, y_test)
# Out:
# Quadratic Discriminant Analysis:
# Accuracy: 0.9561
# Precision: 0.9318
# Recall: 0.9535
# F1 Score: 0.9425
# ROC AUC: 0.9556

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Dictionary to store metrics
metrics = {
    "Model": [],
    "Accuracy": [],
    "Precision": [],
    "Recall": [],
    "F1 Score": [],
    "ROC AUC": []
}

# Function to evaluate model and store results
def evaluate_and_store(model_name, model, x_test, y_test):
    y_pred = model.predict(x_test)
    metrics["Model"].append(model_name)
    metrics["Accuracy"].append(accuracy_score(y_test, y_pred))
    metrics["Precision"].append(precision_score(y_test, y_pred))
    metrics["Recall"].append(recall_score(y_test, y_pred))
    metrics["F1 Score"].append(f1_score(y_test, y_pred))
    metrics["ROC AUC"].append(roc_auc_score(y_test, y_pred))

# List of models to iterate through
models = [
    ("Logistic Regression", LogisticRegression()),
    ("K-Nearest Neighbors", KNeighborsClassifier(n_neighbors=5)),
    ("Support Vector Machine", SVC(kernel='linear', probability=True)),
    ("Decision Tree", DecisionTreeClassifier(random_state=42)),
    ("Random Forest", RandomForestClassifier(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)),
    ("Naive Bayes", GaussianNB()),
    ("Artificial Neural Network", MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42)),
    ("Quadratic Discriminant Analysis", QuadraticDiscriminantAnalysis())
]

# Fit each model and store metrics
for model_name, model in models:
    model.fit(x_train, y_train)
    evaluate_and_store(model_name, model, x_test, y_test)

# Convert metrics to DataFrame
metrics_df = pd.DataFrame(metrics)
print(metrics_df)
# Out:
#                              Model  Accuracy  Precision    Recall  F1 Score  \
# 0              Logistic Regression  0.973684   0.976190  0.953488  0.964706
# 1              K-Nearest Neighbors  0.947368   0.930233  0.930233  0.930233
# 2           Support Vector Machine  0.956140   0.931818  0.953488  0.942529
# 3                    Decision Tree  0.938596   0.909091  0.930233  0.919540
# 4                    Random Forest  0.964912   0.975610  0.930233  0.952381
# 5                Gradient Boosting  0.947368   0.930233  0.930233  0.930233
# 6                      Naive Bayes  0.964912   0.975610  0.930233  0.952381
# 7        Artificial Neural Network  0.964912   0.953488  0.953488  0.953488
# 8  Quadratic Discriminant Analysis  0.956140   0.931818  0.953488  0.942529
#
#     ROC AUC
# 0  0.969702
# 1  0.943990
# 2  0.955617
# 3  0.936947
# 4  0.958074
# 5  0.943990
# 6  0.958074
# 7  0.962660
# 8  0.955617

# %%
# Set up a larger figure
plt.figure(figsize=(12, 8))

# Plot each metric in a separate subplot
metrics_to_plot = ["Accuracy", "Precision", "Recall", "F1 Score", "ROC AUC"]
for i, metric in enumerate(metrics_to_plot, 1):
    plt.subplot(2, 3, i)
    sns.barplot(x="Model", y=metric, data=metrics_df)
    plt.xticks(rotation=45)
    plt.title(f"Model Comparison by {metric}")

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define a color palette for better distinction
palette = sns.color_palette("tab10", len(metrics_df['Model']))

# Set up the figure size
plt.figure(figsize=(16, 12))

# Use metrics to plot and define colors
metrics_to_plot = ["Accuracy", "Precision", "Recall", "F1 Score", "ROC AUC"]

for i, metric in enumerate(metrics_to_plot, 1):
    plt.subplot(3, 2, i)
    
    # Bar plot
    sns.barplot(x="Model", y=metric, data=metrics_df, palette=palette)
    plt.xticks(rotation=45)
    plt.title(f"Bar Plot - Model Comparison by {metric}")
    plt.xlabel("")

    # Line plot
    plt.subplot(3, 2, i + len(metrics_to_plot))
    sns.lineplot(x="Model", y=metric, data=metrics_df, marker="o", sort=False, color="teal")
    plt.xticks(rotation=45)
    plt.title(f"Line Plot - Model Comparison by {metric}")
    plt.xlabel("")

# Adjust layout and display plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\TEST\AppData\Local\Temp\ipykernel_2848\401512032.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Model", y=metric, data=metrics_df, palette=palette)
# C:\Users\TEST\AppData\Local\Temp\ipykernel_2848\401512032.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Model", y=metric, data=metrics_df, palette=palette)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[261], line 24
#      21 plt.xlabel("")
#      23 # Line plot
# ---> 24 plt.subplot(3, 2, i + len(metrics_to_plot))
# ...

# %%
best_model = metrics_df.loc[metrics_df['Accuracy'].idxmax()]
print("Best Model Based on Accuracy:")
print(best_model)
# Out:
# Best Model Based on Accuracy:
# Model        Logistic Regression
# Accuracy                0.973684
# Precision                0.97619
# Recall                  0.953488
# F1 Score                0.964706
# ROC AUC                 0.969702
# Name: 0, dtype: object

# %%
# Function to train logistic regression with specified epochs and collect accuracy
def train_and_evaluate(epochs_list):
    accuracies = []
    for epochs in epochs_list:
        model = SGDClassifier(loss='log_loss', max_iter=epochs, random_state=42, tol=1e-3)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy * 100)  # Convert to percentage
        print(f"Accuracy after {epochs} epochs: {accuracy * 100:.2f}%")
    return accuracies

# Evaluate at different epochs and collect accuracies
epochs_list = [10, 50, 100, 200, 500, 1000]
accuracies = train_and_evaluate(epochs_list)

# Plotting the results
plt.plot(epochs_list, accuracies, marker='o')
plt.title("Logistic Regression Accuracy over Different Epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.grid(True)
plt.show()
# Out:
# Accuracy after 10 epochs: 97.37%
# Accuracy after 50 epochs: 96.49%
# Accuracy after 100 epochs: 96.49%
# Accuracy after 200 epochs: 96.49%
# Accuracy after 500 epochs: 96.49%
# Accuracy after 1000 epochs: 96.49%
# C:\Users\TEST\anaconda3\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:723: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
